# %% [raw]
# Classification Challenge Project
#
# Objective: Build a deep learning model to predict whether a patient has Covid, Pneumonia, or nothing based off of image data.
#
# Given:
#    1. training and testing image datasets.
#
# Expected output:
#    1. A good model.
#    2. Model accuracy over epochs plot
#    3. Confusion matrix

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers
from tensorflow.keras import Input

import matplotlib.pyplot as plt
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\LUKASA~1\AppData\Local\Temp/ipykernel_29248/3772657714.py in <module>
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       5
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
data_generator = ImageDataGenerator(rescale=1.0/255., zoom_range=0.2,rotation_range=15,
                                    width_shift_range=0.05,height_shift_range=0.05)
batch_size = 60
#load training data with iterator 
training_iter = data_generator.flow_from_directory('Covid19-dataset/train',class_mode='categorical',
                                                   color_mode='grayscale',target_size=(256,256),batch_size=batch_size)
x_train,y_train  = training_iter.next()
print(x_train.shape,y_train.shape)

#load testing data
testing_iter = data_generator.flow_from_directory('Covid19-dataset/test',class_mode='categorical',
                                                  color_mode='grayscale',target_size=(256,256),batch_size=batch_size)
x_test,y_test = testing_iter.next()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\LUKASA~1\AppData\Local\Temp/ipykernel_29248/3268107913.py in <module>
# ----> 1 data_generator = ImageDataGenerator(rescale=1.0/255., zoom_range=0.2,rotation_range=15,
#       2                                     width_shift_range=0.05,height_shift_range=0.05)
#       3 batch_size = 60
#       4 #load training data with iterator
#       5 training_iter = data_generator.flow_from_directory('Covid19-dataset/train',class_mode='categorical',
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
#create model
model = Sequential(name='sequential')
model.add(Input(shape=(256,256,1)))
model.add(layers.Conv2D(5,5,strides=3, activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(layers.Dropout(0.1))
model.add(layers.Conv2D(3,3,strides=1, activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(layers.Dropout(0.2))
model.add(layers.Flatten())
model.add(layers.Dense(3,activation='softmax'))

#compile model with adam optimizer and categorical crossentropy loss
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(), 
              metrics = [tf.keras.metrics.CategoricalAccuracy(),tf.keras.metrics.AUC()])

print(model.summary())

es = EarlyStopping(monitor='val_auc', mode='min', verbose=1, patience=20)

# fit the model with 5 ephochs and early stopping
print("\nTraining model...")
history=model.fit(training_iter,steps_per_epoch=len(x_train)/batch_size,epochs=50,validation_data=testing_iter,
          validation_steps=len(x_test)/32,callbacks=[es])

print(history.history)
# plotting categorical and validation accuracy over epochs
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(history.history['categorical_accuracy'])
ax1.plot(history.history['val_categorical_accuracy'])
ax1.set_title('model accuracy')
ax1.set_xlabel('epoch')
ax1.set_ylabel('accuracy')
ax1.legend(['train', 'validation'], loc='upper left')

# plotting auc and validation auc over epochs
# ax2 = fig.add_subplot(2, 1, 2)
# ax2.plot(history.history['auc_9'])
# ax2.plot(history.history['val_auc_9'])
# ax2.set_title('model auc')
# ax2.set_xlabel('epoch')
# ax2.set_ylabel('auc')
# ax2.legend(['train', 'validation'], loc='upper left')

plt.show()


test_steps_per_epoch = numpy.math.ceil(testing_iter.samples / testing_iter.batch_size)
predictions = model.predict(testing_iter, steps=test_steps_per_epoch)
test_steps_per_epoch = numpy.math.ceil(testing_iter.samples / testing_iter.batch_size)
predicted_classes = numpy.argmax(predictions, axis=1)
true_classes = testing_iter.classes
class_labels = list(testing_iter.class_indices.keys())
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)   

cm=confusion_matrix(true_classes,predicted_classes)
print(cm)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 84, 84, 5)         130
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 42, 42, 5)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 42, 42, 5)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 40, 40, 3)         138
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 20, 20, 3)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 20, 20, 3)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 3603
# =================================================================
# Total params: 3,871
# Trainable params: 3,871
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Training model...
# Epoch 1/50
# 1/1 [==============================] - 4s 4s/step - loss: 1.1097 - categorical_accuracy: 0.3000 - auc_4: 0.4375 - val_loss: 1.0999 - val_categorical_accuracy: 0.4242 - val_auc_4: 0.5060
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 2/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.1003 - categorical_accuracy: 0.4000 - auc_4: 0.5216 - val_loss: 1.0950 - val_categorical_accuracy: 0.4394 - val_auc_4: 0.5703
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 3/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0988 - categorical_accuracy: 0.4333 - auc_4: 0.5154 - val_loss: 1.0981 - val_categorical_accuracy: 0.4091 - val_auc_4: 0.5094
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 4/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0798 - categorical_accuracy: 0.3667 - auc_4: 0.6428 - val_loss: 1.0950 - val_categorical_accuracy: 0.4091 - val_auc_4: 0.5391
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 5/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0789 - categorical_accuracy: 0.4500 - auc_4: 0.6062 - val_loss: 1.0917 - val_categorical_accuracy: 0.4091 - val_auc_4: 0.5782
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 6/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0789 - categorical_accuracy: 0.4667 - auc_4: 0.5898 - val_loss: 1.0935 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.5344
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 7/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0651 - categorical_accuracy: 0.4167 - auc_4: 0.6382 - val_loss: 1.0915 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.5426
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 8/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0763 - categorical_accuracy: 0.4333 - auc_4: 0.5860 - val_loss: 1.0934 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.5302
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 9/50
# 1/1 [==============================] - 1s 778ms/step - loss: 1.0756 - categorical_accuracy: 0.2727 - auc_4: 0.6405 - val_loss: 1.0939 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.5106
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 10/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0326 - categorical_accuracy: 0.5000 - auc_4: 0.6864 - val_loss: 1.0911 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.5458
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 11/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0871 - categorical_accuracy: 0.4000 - auc_4: 0.5692 - val_loss: 1.0841 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.5808
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 12/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0456 - categorical_accuracy: 0.4167 - auc_4: 0.6658 - val_loss: 1.0797 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.6157
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 13/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0350 - categorical_accuracy: 0.5000 - auc_4: 0.6519 - val_loss: 1.0876 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.5584
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 14/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0466 - categorical_accuracy: 0.4833 - auc_4: 0.6335 - val_loss: 1.0759 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.6082
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 15/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0270 - categorical_accuracy: 0.4833 - auc_4: 0.6776 - val_loss: 1.0828 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.5719
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 16/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0272 - categorical_accuracy: 0.4500 - auc_4: 0.7063 - val_loss: 1.0772 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.6094
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 17/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0396 - categorical_accuracy: 0.4333 - auc_4: 0.6553 - val_loss: 1.0696 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.6309
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 18/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0837 - categorical_accuracy: 0.4000 - auc_4: 0.5849 - val_loss: 1.0737 - val_categorical_accuracy: 0.3939 - val_auc_4: 0.6119
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 19/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0010 - categorical_accuracy: 0.4833 - auc_4: 0.7117 - val_loss: 1.0639 - val_categorical_accuracy: 0.4091 - val_auc_4: 0.6346
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 20/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.9873 - categorical_accuracy: 0.5000 - auc_4: 0.7293 - val_loss: 1.0452 - val_categorical_accuracy: 0.4091 - val_auc_4: 0.6751
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 21/50
# 1/1 [==============================] - 1s 1s/step - loss: 1.0422 - categorical_accuracy: 0.3833 - auc_4: 0.6716 - val_loss: 1.0562 - val_categorical_accuracy: 0.4242 - val_auc_4: 0.6455
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 22/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.9960 - categorical_accuracy: 0.5000 - auc_4: 0.7083 - val_loss: 1.0418 - val_categorical_accuracy: 0.4394 - val_auc_4: 0.6904
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 23/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.9130 - categorical_accuracy: 0.6667 - auc_4: 0.8193 - val_loss: 1.0261 - val_categorical_accuracy: 0.4697 - val_auc_4: 0.7137
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 24/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.9506 - categorical_accuracy: 0.5833 - auc_4: 0.7567 - val_loss: 1.0160 - val_categorical_accuracy: 0.5000 - val_auc_4: 0.7192
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 25/50
# 1/1 [==============================] - 3s 3s/step - loss: 0.9723 - categorical_accuracy: 0.4167 - auc_4: 0.7246 - val_loss: 1.0247 - val_categorical_accuracy: 0.4848 - val_auc_4: 0.7021
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 26/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.9369 - categorical_accuracy: 0.6000 - auc_4: 0.7972 - val_loss: 1.0296 - val_categorical_accuracy: 0.5303 - val_auc_4: 0.6886
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 27/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.9226 - categorical_accuracy: 0.6000 - auc_4: 0.7984 - val_loss: 1.0127 - val_categorical_accuracy: 0.5758 - val_auc_4: 0.7290
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 28/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.9271 - categorical_accuracy: 0.6000 - auc_4: 0.8037 - val_loss: 1.0075 - val_categorical_accuracy: 0.5303 - val_auc_4: 0.7276
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 29/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.9609 - categorical_accuracy: 0.5455 - auc_4: 0.7293 - val_loss: 0.9827 - val_categorical_accuracy: 0.5606 - val_auc_4: 0.7658
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 30/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.9646 - categorical_accuracy: 0.5333 - auc_4: 0.7263 - val_loss: 0.9631 - val_categorical_accuracy: 0.6212 - val_auc_4: 0.8117
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 31/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8709 - categorical_accuracy: 0.7333 - auc_4: 0.8451 - val_loss: 0.9895 - val_categorical_accuracy: 0.6667 - val_auc_4: 0.7639
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 32/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8978 - categorical_accuracy: 0.6833 - auc_4: 0.8331 - val_loss: 0.9395 - val_categorical_accuracy: 0.7273 - val_auc_4: 0.8299
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 33/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.9252 - categorical_accuracy: 0.6667 - auc_4: 0.7859 - val_loss: 0.9566 - val_categorical_accuracy: 0.6515 - val_auc_4: 0.7838
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 34/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8244 - categorical_accuracy: 0.7333 - auc_4: 0.8810 - val_loss: 0.9500 - val_categorical_accuracy: 0.6212 - val_auc_4: 0.7765
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 35/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8341 - categorical_accuracy: 0.7167 - auc_4: 0.8519 - val_loss: 0.9304 - val_categorical_accuracy: 0.5909 - val_auc_4: 0.7982
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 36/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8413 - categorical_accuracy: 0.7167 - auc_4: 0.8555 - val_loss: 0.9039 - val_categorical_accuracy: 0.6061 - val_auc_4: 0.8309
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 37/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.7885 - categorical_accuracy: 0.6500 - auc_4: 0.8628 - val_loss: 0.9197 - val_categorical_accuracy: 0.5606 - val_auc_4: 0.7918
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 38/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.7550 - categorical_accuracy: 0.7273 - auc_4: 0.8636 - val_loss: 0.8542 - val_categorical_accuracy: 0.6667 - val_auc_4: 0.8432
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch 39/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.7805 - categorical_accuracy: 0.6500 - auc_4: 0.8643 - val_loss: 0.9258 - val_categorical_accuracy: 0.5303 - val_auc_4: 0.7622
# WARNING:tensorflow:Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: loss,categorical_accuracy,auc_4,val_loss,val_categorical_accuracy,val_auc_4
# Epoch